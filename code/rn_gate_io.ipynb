# %%
import sys
# !{sys.executable} -m pip install gate_api
# Out:
# Requirement already satisfied: gate_api in /opt/conda/lib/python3.8/site-packages (4.21.6)
# Requirement already satisfied: urllib3>=1.15 in /opt/conda/lib/python3.8/site-packages (from gate_api) (1.26.2)
# Requirement already satisfied: certifi in /opt/conda/lib/python3.8/site-packages (from gate_api) (2020.12.5)
# Requirement already satisfied: python-dateutil in /opt/conda/lib/python3.8/site-packages (from gate_api) (2.8.1)
# Requirement already satisfied: six>=1.10 in /opt/conda/lib/python3.8/site-packages (from gate_api) (1.15.0)

# %%
import requests
import pandas as pd
from datetime import datetime

host = "https://api.gateio.ws"
prefix = "/api/v4"
headers = {'Accept': 'application/json', 'Content-Type': 'application/json'}

# %%
# get all currency pairs
url = '/spot/currencies'
r = requests.request('GET', host + prefix + url, headers=headers)
r.json()
# Out:
# [{'currency': 'CREDIT',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'STPT',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'UGT',
#   'delisted': True,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'GRIN3L',
#   'delisted': False,
#   'withdraw_disabled': True,
#   'withdraw_delayed': False,
#   'deposit_disabled': True,
#   'trade_disabled': False},
#  {'currency': 'RENBTC',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'QTUM_ETH',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'BBK',
#   'delisted': True,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'DFL',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'NEAR',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'HNS',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'AUDIO',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'AIOZ',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'SAKE',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'HNT',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'SAL0',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'FARM',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'VET3S',
#   'delisted': False,
#   'withdraw_disabled': True,
#   'withdraw_delayed': False,
#   'deposit_disabled': True,
#   'trade_disabled': False},
#  {'currency': 'TIDAL',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'SDN',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'DBC_ETH',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'HOD',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'GRIN3S',
#   'delisted': False,
#   'withdraw_disabled': True,
#   'withdraw_delayed': False,
#   'deposit_disabled': True,
#   'trade_disabled': False},
#  {'currency': 'SNX3L',
#   'delisted': False,
#   'withdraw_disabled': True,
#   'withdraw_delayed': False,
#   'deposit_disabled': True,
#   'trade_disabled': False},
#  {'currency': 'BCD',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'WING',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'AE',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'BCH',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'SERO',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'JST',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'SNX3S',
#   'delisted': False,
#   'withdraw_disabled': True,
#   'withdraw_delayed': False,
#   'deposit_disabled': True,
#   'trade_disabled': False},
#  {'currency': 'HOT',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'BCN',
#   'delisted': False,
#   'withdraw_disabled': True,
#   'withdraw_delayed': False,
#   'deposit_disabled': True,
#   'trade_disabled': False},
#  {'currency': 'STOX',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'AR',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'BCX',
#   'delisted': False,
#   'withdraw_disabled': True,
#   'withdraw_delayed': False,
#   'deposit_disabled': True,
#   'trade_disabled': False},
#  {'currency': 'YFDAI',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'SAFEMARS',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'POOL',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'MDX_BSC',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'HPB',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'SEN',
#   'delisted': True,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'WOZX',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'LION',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'QASH',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': True,
#   'trade_disabled': False},
#  {'currency': 'BDB',
#   'delisted': True,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'COVER',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'FLM',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'MARSH',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'FIDA0',
#   'delisted': True,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'HT_TRX',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'BDP',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'EGLD3S',
#   'delisted': False,
#   'withdraw_disabled': True,
#   'withdraw_delayed': False,
#   'deposit_disabled': True,
#   'trade_disabled': False},
#  {'currency': 'FLY',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'DHV',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'BDT',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'BU',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': True,
#   'trade_disabled': True},
#  {'currency': 'SFG',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'DHX',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'BSV5L',
#   'delisted': False,
#   'withdraw_disabled': True,
#   'withdraw_delayed': False,
#   'deposit_disabled': True,
#   'trade_disabled': False},
#  {'currency': 'SFI',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'BABYDOGE',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'EGLD3L',
#   'delisted': False,
#   'withdraw_disabled': True,
#   'withdraw_delayed': False,
#   'deposit_disabled': True,
#   'trade_disabled': False},
#  {'currency': 'SFP',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'DIA',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'LYM',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'USDT_SOL',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'VET3L',
#   'delisted': False,
#   'withdraw_disabled': True,
#   'withdraw_delayed': False,
#   'deposit_disabled': True,
#   'trade_disabled': False},
#  {'currency': 'ROSE3S',
#   'delisted': False,
#   'withdraw_disabled': True,
#   'withdraw_delayed': False,
#   'deposit_disabled': True,
#   'trade_disabled': False},
#  {'currency': 'QBT',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'EIEC',
#   'delisted': True,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'ROSE3L',
#   'delisted': False,
#   'withdraw_disabled': True,
#   'withdraw_delayed': False,
#   'deposit_disabled': True,
#   'trade_disabled': False},
#  {'currency': 'BEL',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'BSV5S',
#   'delisted': False,
#   'withdraw_disabled': True,
#   'withdraw_delayed': False,
#   'deposit_disabled': True,
#   'trade_disabled': False},
#  {'currency': 'SNET',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'HT_ETH',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'DIS',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'SALT',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'CS',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'WOM',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'NAS_ETH',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'WOO',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'SRM3S',
#   'delisted': False,
#   'withdraw_disabled': True,
#   'withdraw_delayed': False,
#   'deposit_disabled': True,
#   'trade_disabled': False},
#  {'currency': 'IOET',
#   'delisted': True,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'ARCX',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'FAST',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': True,
#   'trade_disabled': False},
#  {'currency': 'BFC',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'PRARE',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'SRM3L',
#   'delisted': False,
#   'withdraw_disabled': True,
#   'withdraw_delayed': False,
#   'deposit_disabled': True,
#   'trade_disabled': False},
#  {'currency': 'ARES',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'STARL',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'DF',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'DG',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'SUSHI3L',
#   'delisted': False,
#   'withdraw_disabled': True,
#   'withdraw_delayed': False,
#   'deposit_disabled': True,
#   'trade_disabled': False},
#  {'currency': '100X',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'SHOPX',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'BFT',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'WAVES',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'HAPI',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'DX',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'SUSHI3S',
#   'delisted': False,
#   'withdraw_disabled': True,
#   'withdraw_delayed': False,
#   'deposit_disabled': True,
#   'trade_disabled': False},
#  {'currency': 'BSV3L',
#   'delisted': False,
#   'withdraw_disabled': True,
#   'withdraw_delayed': False,
#   'deposit_disabled': True,
#   'trade_disabled': False},
#  {'currency': 'USD_PAXETH',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'DUCK',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'HSC',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'DKA',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'SEXC',
#   'delisted': True,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'SHR',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'MED_QTUM',
#   'delisted': False,
#   'withdraw_disabled': True,
#   'withdraw_delayed': False,
#   'deposit_disabled': True,
#   'trade_disabled': False},
#  {'currency': 'BSCS',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'ULU',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': True,
#   'trade_disabled': False},
#  {'currency': 'CUDOS',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'PEARL',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'SAND',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'LABS',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'STAR0',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'USD_BUSDETH',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'BEPRO',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'UMA',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'FOR',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'UMB',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'BSV3S',
#   'delisted': False,
#   'withdraw_disabled': True,
#   'withdraw_delayed': False,
#   'deposit_disabled': True,
#   'trade_disabled': False},
#  {'currency': 'WTHC',
#   'delisted': True,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'SCRT',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'EZ',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'TUSD',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'RBTC',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'PMON',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'ETHA0',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'UMX',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'ADA3L',
#   'delisted': False,
#   'withdraw_disabled': True,
#   'withdraw_delayed': False,
#   'deposit_disabled': True,
#   'trade_disabled': False},
#  {'currency': 'OAX',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'HARD',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'EGG0',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'LEND',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': True},
#  {'currency': 'ADA3S',
#   'delisted': False,
#   'withdraw_disabled': True,
#   'withdraw_delayed': False,
#   'deposit_disabled': True,
#   'trade_disabled': False},
#  {'currency': 'UNI',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'MEETONE_ETH',
#   'delisted': False,
#   'withdraw_disabled': True,
#   'withdraw_delayed': False,
#   'deposit_disabled': True,
#   'trade_disabled': False},
#  {'currency': 'UNN',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'DLTA',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'DNXC',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'USDT_OKT',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'WRX',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'ROOMV1',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'O3_BSC',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'TLOS_ETH',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'WHITE',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'PERI_MATIC',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'CRBN',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'HUR',
#   'delisted': True,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'AMPL3S',
#   'delisted': False,
#   'withdraw_disabled': True,
#   'withdraw_delayed': False,
#   'deposit_disabled': True,
#   'trade_disabled': False},
#  {'currency': 'PYR_MATIC',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'GO',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'UNCX',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'ZIL_ETH',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'WSG',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'DMT',
#   'delisted': True,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'NCASH',
#   'delisted': True,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'GS',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'BIT',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'AMPL3L',
#   'delisted': False,
#   'withdraw_disabled': True,
#   'withdraw_delayed': False,
#   'deposit_disabled': True,
#   'trade_disabled': False},
#  {'currency': 'GT',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'DOGGY',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'OCC',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'SWINGBY',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'LEMD',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'NKN_ETH',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'FRA',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'SKM',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'SKL',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'HAI_ETH',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'UOS',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'LEMO',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'OCN',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'HC',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'ROOM',
#   'delisted': False,
#   'withdraw_disabled': True,
#   'withdraw_delayed': False,
#   'deposit_disabled': True,
#   'trade_disabled': False},
#  {'currency': 'SKT',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'ROOK',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'STRONG',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'USDT0_HT',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'HVN',
#   'delisted': True,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'YFX_HT',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'BUSD0',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'GRT3S',
#   'delisted': False,
#   'withdraw_disabled': True,
#   'withdraw_delayed': False,
#   'deposit_disabled': True,
#   'trade_disabled': False},
#  {'currency': 'DNT',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'HT',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'GRT3L',
#   'delisted': False,
#   'withdraw_disabled': True,
#   'withdraw_delayed': False,
#   'deposit_disabled': True,
#   'trade_disabled': False},
#  {'currency': 'FLOW',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'ODDZ',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'LION_ETH',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'NSURE',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'ATMI',
#   'delisted': True,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'GTC_HT',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'QKC_ETH',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'UPP',
#   'delisted': True,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'SLM',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'SLP',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'ANTV1',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'SLIM',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'BKC',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'ETC0',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'DOG',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'FSN',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'DOP',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'FST',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'DOT',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'ZEN3L',
#   'delisted': False,
#   'withdraw_disabled': True,
#   'withdraw_delayed': False,
#   'deposit_disabled': True,
#   'trade_disabled': False},
#  {'currency': 'IQ',
#   'delisted': True,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'DOS',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'TRX_ETH',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': True},
#  {'currency': 'XRP5S',
#   'delisted': False,
#   'withdraw_disabled': True,
#   'withdraw_delayed': False,
#   'deposit_disabled': True,
#   'trade_disabled': False},
#  {'currency': 'BKX',
#   'delisted': True,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': '1INCH',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'ARGON',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'XRP5L',
#   'delisted': False,
#   'withdraw_disabled': True,
#   'withdraw_delayed': False,
#   'deposit_disabled': True,
#   'trade_disabled': False},
#  {'currency': 'CLV_BSC',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'WGRT',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'FTI',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'UNFI',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'SMT',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'MAN',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'FTM',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'POWR',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'HXT',
#   'delisted': True,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'FTT',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'DPR',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'ALAYA',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'DPY',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'MOBI',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'BLY',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'ATOM',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'QUICK',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'BLZ',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'WNCG',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'TRX3L',
#   'delisted': False,
#   'withdraw_disabled': True,
#   'withdraw_delayed': False,
#   'deposit_disabled': True,
#   'trade_disabled': False},
#  {'currency': 'MBL',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'ZEN3S',
#   'delisted': False,
#   'withdraw_disabled': True,
#   'withdraw_delayed': False,
#   'deposit_disabled': True,
#   'trade_disabled': False},
#  {'currency': 'SNT',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'ALPHA_BSC',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'KSM3L',
#   'delisted': False,
#   'withdraw_disabled': True,
#   'withdraw_delayed': False,
#   'deposit_disabled': True,
#   'trade_disabled': False},
#  {'currency': 'TRX3S',
#   'delisted': False,
#   'withdraw_disabled': True,
#   'withdraw_delayed': False,
#   'deposit_disabled': True,
#   'trade_disabled': False},
#  {'currency': 'SNX',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'SUN_OLD',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'FUN',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'BMI',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'AVAX3L',
#   'delisted': False,
#   'withdraw_disabled': True,
#   'withdraw_delayed': False,
#   'deposit_disabled': True,
#   'trade_disabled': False},
#  {'currency': 'KSM3S',
#   'delisted': False,
#   'withdraw_disabled': True,
#   'withdraw_delayed': False,
#   'deposit_disabled': True,
#   'trade_disabled': False},
#  {'currency': 'USC',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'USD',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'API3',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'XRP3S',
#   'delisted': False,
#   'withdraw_disabled': True,
#   'withdraw_delayed': False,
#   'deposit_disabled': True,
#   'trade_disabled': False},
#  {'currency': 'QKC',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'ROSE',
#   'delisted': False,
#   'withdraw_disabled': True,
#   'withdraw_delayed': False,
#   'deposit_disabled': True,
#   'trade_disabled': False},
#  {'currency': 'AVAX3S',
#   'delisted': False,
#   'withdraw_disabled': True,
#   'withdraw_delayed': False,
#   'deposit_disabled': True,
#   'trade_disabled': False},
#  {'currency': 'SOL',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'XRP3L',
#   'delisted': False,
#   'withdraw_disabled': True,
#   'withdraw_delayed': False,
#   'deposit_disabled': True,
#   'trade_disabled': False},
#  {'currency': 'SOP',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'BNC',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'UST',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'OGN',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'CELR',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'BNB',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'MCO',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': True},
#  {'currency': 'TOMO',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'COCOS_BSC',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'CELO',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'AUCTION',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'BADGER',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'LAYER',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'SUSHI0_BSC',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'USDC_SOL',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'BNL',
#   'delisted': True,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'SPA',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'WEST',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'QLC',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'BNT',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'MDA',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'UTK',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'SPI',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'EOSBEAR',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'WXT',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'HEGIC',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'NEO3S',
#   'delisted': False,
#   'withdraw_disabled': True,
#   'withdraw_delayed': False,
#   'deposit_disabled': True,
#   'trade_disabled': False},
#  {'currency': 'DSD',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'BOA',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'FUEL',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'SPS',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'KTN_BSC',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'BOE',
#   'delisted': False,
#   'withdraw_disabled': True,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': True},
#  {'currency': 'NEO3L',
#   'delisted': False,
#   'withdraw_disabled': True,
#   'withdraw_delayed': False,
#   'deposit_disabled': True,
#   'trade_disabled': False},
#  {'currency': 'MDT',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'MDS',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'DOGE_HT',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'MM',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'MDX',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'AERGO',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'BOR',
#   'delisted': False,
#   'withdraw_disabled': True,
#   'withdraw_delayed': False,
#   'deposit_disabled': True,
#   'trade_disabled': True},
#  {'currency': 'ARNX',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': True,
#   'trade_disabled': False},
#  {'currency': 'SNOW',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'BOT',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': True},
#  {'currency': 'DFND',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'CTK_BSC',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'DDD_1',
#   'delisted': True,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
# ...
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'WINGS',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': True},
#  {'currency': 'PHA',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'RLC',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'XEND',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'FIL6',
#   'delisted': False,
#   'withdraw_disabled': True,
#   'withdraw_delayed': False,
#   'deposit_disabled': True,
#   'trade_disabled': False},
#  {'currency': 'ORBS',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'CRV3S',
#   'delisted': False,
#   'withdraw_disabled': True,
#   'withdraw_delayed': False,
#   'deposit_disabled': True,
#   'trade_disabled': False},
#  {'currency': 'CRV3L',
#   'delisted': False,
#   'withdraw_disabled': True,
#   'withdraw_delayed': False,
#   'deposit_disabled': True,
#   'trade_disabled': False},
#  {'currency': 'ESD',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'HORD',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'TPT',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'BOX_1',
#   'delisted': True,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'RLY',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'BTMX',
#   'delisted': False,
#   'withdraw_disabled': True,
#   'withdraw_delayed': False,
#   'deposit_disabled': True,
#   'trade_disabled': True},
#  {'currency': 'ESS',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'COS',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'HOPR',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'AKT',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'XYM',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'ORAI',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'PIG',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'CHAIN',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'COVER_OLD',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'ORAO',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'KALM',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'ETC',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'BAGS',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'BTMC',
#   'delisted': True,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'ETH',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'NEO',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'KLAY',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'TARA',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'TOMOE0',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'DUCK2',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'LAT',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'TOOLS',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'YASHA',
#   'delisted': True,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'TRADE',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'PDEX',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'HOT0',
#   'delisted': True,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'ALN',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'SRM_SOL',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'GXS',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'TRB',
#   'delisted': False,
#   'withdraw_disabled': True,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'RNB',
#   'delisted': True,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'LBA',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'BTC_BSC',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'VALUE',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'ALY',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'FLY_BSC',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'LBK',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'TRU',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'AME',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'DREP',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'FINE',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'TRX',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'NFT',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'GTEVM',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'AMP',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'NEAR3L',
#   'delisted': False,
#   'withdraw_disabled': True,
#   'withdraw_delayed': False,
#   'deposit_disabled': True,
#   'trade_disabled': False},
#  {'currency': 'CQT',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'PKF',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'NULS',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'RFUEL',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'TSL',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': True,
#   'trade_disabled': False},
#  {'currency': 'NEAR3S',
#   'delisted': False,
#   'withdraw_disabled': True,
#   'withdraw_delayed': False,
#   'deposit_disabled': True,
#   'trade_disabled': False},
#  {'currency': 'MAHA',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'FTBC',
#   'delisted': True,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'AUTO',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'SKM-CDY',
#   'delisted': True,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'CRC',
#   'delisted': True,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'ANC',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'CRE',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'USDC_TRX',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'PKS',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'RAZE',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'PLUS',
#   'delisted': True,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'CRP',
#   'delisted': False,
#   'withdraw_disabled': True,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'CRO',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'PLA',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'CRT',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'CRV',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'ANT',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'CRU',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'BAKE',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'ANY',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'HGET',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'DRGN',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'SOUL',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'ALICE',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'CSM',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'PLY',
#   'delisted': True,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'PROPS',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'DADI',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': True},
#  {'currency': 'MATTER',
#   'delisted': False,
#   'withdraw_disabled': True,
#   'withdraw_delayed': False,
#   'deposit_disabled': True,
#   'trade_disabled': False},
#  {'currency': 'EWT',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'TUC',
#   'delisted': True,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'USDT_EOS',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'GDAO',
#   'delisted': False,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  {'currency': 'EXC',
#   'delisted': True,
#   'withdraw_disabled': False,
#   'withdraw_delayed': False,
#   'deposit_disabled': False,
#   'trade_disabled': False},
#  ...]

# %%
# get currency pair info
url = '/spot/currencies/GT'
query_param = 'currency_pair=DOGE_USDT'
r = requests.request('GET', host + prefix + url + "?" + query_param, headers=headers)
r.json()
# Out:
# {'currency': 'GT',
#  'delisted': False,
#  'withdraw_disabled': False,
#  'withdraw_delayed': False,
#  'deposit_disabled': False,
#  'trade_disabled': False}

# %% [markdown]
# ### Historical Data (candelsticks)
# + limited to 1000 per pull.  Can download more to csv from the website
# + https://www.gate.io/en/developer/historical_quotes
# + https://www.gate.io/docs/developers/apiv4/en/#market-candlesticks

# %%
# candlesticks = historical data by interval.  Limited to 1000
url = '/spot/candlesticks'
pair = 'BTC_USDT'
interval = '1d'
query_param = 'currency_pair='+pair+'&'+'interval='+interval
cols = ['timestamp','volume','close','high','low','open']

# get, convert to df
r = requests.request('GET', host + prefix + url + "?" + query_param, headers=headers)
df = pd.DataFrame(list(r.json()),columns = cols)

# add the currency pair, convert unix timestamp to date and set as the index
df['pair'] = pair
df['date'] = df.timestamp.apply(lambda x:datetime.utcfromtimestamp(int(x)).strftime('%Y-%m-%d %H:%M:%S'))
df.set_index('date',inplace=True)
df.drop(['timestamp'],axis=1,inplace=True)

df.head()
# Out:
#                                            volume     close      high  \
# date
# 2021-05-16 00:00:00     155000727.331137982848047  46434.14   49777.4
# 2021-05-17 00:00:00     192324747.872776226163361  43550.75  46613.25
# 2021-05-18 00:00:00     139869239.552834866366068  42849.89  45782.63
# 2021-05-19 00:00:00  489307863.858910411065444107  36662.15  43591.94
# 2021-05-20 00:00:00     321546290.995153450628666  40548.02  42409.35
#
#                           low      open      pair
# date
# 2021-05-16 00:00:00     43890  46791.01  BTC_USDT
# 2021-05-17 00:00:00     42101  46434.93  BTC_USDT
# 2021-05-18 00:00:00  42291.13  43547.39  BTC_USDT
# 2021-05-19 00:00:00     29800  42854.18  BTC_USDT
# 2021-05-20 00:00:00  34908.82  36669.73  BTC_USDT

# %%
# historical download of data
# hourly data by month- requirs a download per month
btc = pd.read_csv('../data/BTC_USDT.csv',header=None,names=cols)
btc['pair'] = 'BTC_USDT'
btc['date'] = btc.timestamp.apply(lambda x:datetime.utcfromtimestamp(int(x)).strftime('%Y-%m-%d %H:%M:%S'))
btc.set_index('date',inplace=True)
btc.drop(['timestamp'],axis=1,inplace=True)
btc
# Out:
#                         volume         close          high           low  \
# date
# 2018-01-31 23:00:00  14.227681  10313.077462  10314.058075  10150.849999
# 2018-01-31 22:00:00   5.991346  10194.550147  10288.156528  10127.269877
# 2018-01-31 21:00:00   3.364490  10105.750000  10199.960041  10001.000000
# 2018-01-31 20:00:00   5.144728  10177.590000  10210.001155  10062.730000
# 2018-01-31 19:00:00   7.451171  10069.100000  10200.000000  10030.399999
# ...                        ...           ...           ...           ...
# 2018-01-01 04:00:00  17.580909  13499.000551  13500.015726  13103.299999
# 2018-01-01 03:00:00  29.545778  13289.000000  13504.756757  13200.130000
# 2018-01-01 02:00:00  25.614961  13248.279157  13386.881606  13112.580000
# 2018-01-01 01:00:00  14.945871  13197.659998  13597.346807  13112.580000
# 2018-01-01 00:00:00   4.297314  13578.128370  13730.370000  13425.060000
#
#                              open      pair
# date
# 2018-01-31 23:00:00  10203.319998  BTC_USDT
# 2018-01-31 22:00:00  10146.486278  BTC_USDT
# 2018-01-31 21:00:00  10178.329998  BTC_USDT
# 2018-01-31 20:00:00  10076.110000  BTC_USDT
# 2018-01-31 19:00:00  10098.993436  BTC_USDT
# ...                           ...       ...
# 2018-01-01 04:00:00  13289.000000  BTC_USDT
# 2018-01-01 03:00:00  13248.279157  BTC_USDT
# 2018-01-01 02:00:00  13308.950000  BTC_USDT
# 2018-01-01 01:00:00  13480.000000  BTC_USDT
# 2018-01-01 00:00:00  13588.000000  BTC_USDT
#
# [744 rows x 6 columns]
